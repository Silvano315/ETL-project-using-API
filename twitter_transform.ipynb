# %% [markdown]
# # ETL Twitter Project: Transform step

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from datetime import datetime

# %% [markdown]
# ## 2. Load Json Dataset

# %%
# Load JSON file

with open('Data/Twitter_User.json') as f:
    data = pd.read_json(f)

df = pd.json_normalize(data['data'])

df.head()
# Out:
#                                                    0  \
# 0  {'rest_id': '1826311206619197553', 'is_transla...
# 1                                               None
#
#                                                    1  \
# 0  {'rest_id': '1826311206602195156', 'is_transla...
# 1                                               None
#
#                                                    2
# 0  {'rest_id': '1826311206086606998', 'is_transla...
# 1                                               None

# %%
df.iloc[0,0]
# Out:
# {'rest_id': '1826311206619197553',
#  'is_translatable': False,
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'core.user_results.result.__typename': 'User',
#  'core.user_results.result.id': 'VXNlcjoyMDYzNDkzOQ==',
#  'core.user_results.result.rest_id': '20634939',
#  'core.user_results.result.has_graduated_access': True,
#  'core.user_results.result.is_blue_verified': False,
#  'core.user_results.result.profile_image_shape': 'Circle',
#  'core.user_results.result.legacy.can_dm': True,
#  'core.user_results.result.legacy.can_media_tag': False,
#  'core.user_results.result.legacy.created_at': 'Wed Feb 11 22:24:11 +0000 2009',
#  'core.user_results.result.legacy.default_profile': False,
#  'core.user_results.result.legacy.default_profile_image': False,
#  'core.user_results.result.legacy.description': 'Light Shall Defeat Darkness',
#  'core.user_results.result.legacy.entities.description.urls': [],
#  'core.user_results.result.legacy.fast_followers_count': 0,
#  'core.user_results.result.legacy.favourites_count': 591089,
#  'core.user_results.result.legacy.followers_count': 5063,
#  'core.user_results.result.legacy.friends_count': 2320,
#  'core.user_results.result.legacy.has_custom_timelines': True,
#  'core.user_results.result.legacy.is_translator': False,
#  'core.user_results.result.legacy.listed_count': 157,
#  'core.user_results.result.legacy.location': '',
#  'core.user_results.result.legacy.media_count': 31319,
#  'core.user_results.result.legacy.name': 'SiaAyrom',
#  'core.user_results.result.legacy.normal_followers_count': 5063,
#  'core.user_results.result.legacy.pinned_tweet_ids_str': ['1826098151091998807'],
#  'core.user_results.result.legacy.possibly_sensitive': False,
#  'core.user_results.result.legacy.profile_banner_url': 'https://pbs.twimg.com/profile_banners/20634939/1689277662',
#  'core.user_results.result.legacy.profile_image_url_https': 'https://pbs.twimg.com/profile_images/1719704016358100993/EI4sUUOA_normal.jpg',
#  'core.user_results.result.legacy.profile_interstitial_type': '',
#  'core.user_results.result.legacy.screen_name': 'siaayrom',
#  'core.user_results.result.legacy.statuses_count': 622054,
#  'core.user_results.result.legacy.translator_type': 'none',
#  'core.user_results.result.legacy.verified': False,
#  'core.user_results.result.legacy.want_retweets': False,
#  'core.user_results.result.legacy.withheld_in_countries': [],
#  'card.rest_id': 'https://t.co/ldzoGfJhLj',
#  'card.legacy.binding_values': [{'key': 'photo_image_full_size_large',
#    'value': {'image_value': {'height': 419,
#      'width': 800,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=800x419'},
#     'type': 'IMAGE'}},
#   {'key': 'thumbnail_image',
#    'value': {'image_value': {'height': 200,
#      'width': 600,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=600x600'},
#     'type': 'IMAGE'}},
#   {'key': 'description',
#    'value': {'string_value': "Documentation and source code powering Twitter's Community Notes - twitter/communitynotes",
#     'type': 'STRING'}},
#   {'key': 'domain', 'value': {'string_value': 'github.com', 'type': 'STRING'}},
#   {'key': 'thumbnail_image_large',
#    'value': {'image_value': {'height': 333,
#      'width': 1000,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=1000x1000'},
#     'type': 'IMAGE'}},
#   {'key': 'summary_photo_image_small',
#    'value': {'image_value': {'height': 202,
#      'width': 386,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=386x202'},
#     'type': 'IMAGE'}},
#   {'key': 'thumbnail_image_original',
#    'value': {'image_value': {'height': 500,
#      'width': 1500,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=orig'},
#     'type': 'IMAGE'}},
#   {'key': 'site',
#    'value': {'scribe_key': 'publisher_id',
#     'type': 'USER',
#     'user_value': {'id_str': '13334762', 'path': []}}},
#   {'key': 'photo_image_full_size_small',
#    'value': {'image_value': {'height': 202,
#      'width': 386,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=386x202'},
#     'type': 'IMAGE'}},
#   {'key': 'summary_photo_image_large',
#    'value': {'image_value': {'height': 419,
#      'width': 800,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=800x419'},
#     'type': 'IMAGE'}},
#   {'key': 'thumbnail_image_small',
#    'value': {'image_value': {'height': 80,
#      'width': 240,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=240x240'},
#     'type': 'IMAGE'}},
#   {'key': 'thumbnail_image_x_large',
#    'value': {'image_value': {'height': 500,
#      'width': 1500,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=png&name=2048x2048_2_exp'},
#     'type': 'IMAGE'}},
#   {'key': 'photo_image_full_size_original',
#    'value': {'image_value': {'height': 500,
#      'width': 1500,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=orig'},
#     'type': 'IMAGE'}},
#   {'key': 'photo_image_full_size_alt_text',
#    'value': {'string_value': "Documentation and source code powering Twitter's Community Notes - twitter/communitynotes",
#     'type': 'STRING'}},
#   {'key': 'vanity_url',
#    'value': {'scribe_key': 'vanity_url',
#     'string_value': 'github.com',
#     'type': 'STRING'}},
#   {'key': 'photo_image_full_size',
#    'value': {'image_value': {'height': 314,
#      'width': 600,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=600x314'},
#     'type': 'IMAGE'}},
#   {'key': 'summary_photo_image_alt_text',
#    'value': {'string_value': "Documentation and source code powering Twitter's Community Notes - twitter/communitynotes",
#     'type': 'STRING'}},
#   {'key': 'thumbnail_image_color',
#    'value': {'image_color_value': {'palette': [{'rgb': {'blue': 182,
#         'green': 237,
#         'red': 69},
#        'percentage': 47.44},
#       {'rgb': {'blue': 247, 'green': 161, 'red': 17}, 'percentage': 20.44},
#       {'rgb': {'blue': 215, 'green': 201, 'red': 44}, 'percentage': 14.95},
#       {'rgb': {'blue': 229, 'green': 180, 'red': 30}, 'percentage': 7.43},
#       {'rgb': {'blue': 244, 'green': 241, 'red': 225}, 'percentage': 4.69}]},
#     'type': 'IMAGE_COLOR'}},
#   {'key': 'title',
#    'value': {'string_value': "GitHub - twitter/communitynotes: Documentation and source code powering Twitter's Community Notes",
#     'type': 'STRING'}},
#   {'key': 'summary_photo_image_color',
#    'value': {'image_color_value': {'palette': [{'rgb': {'blue': 182,
#         'green': 237,
#         'red': 69},
#        'percentage': 47.44},
#       {'rgb': {'blue': 247, 'green': 161, 'red': 17}, 'percentage': 20.44},
#       {'rgb': {'blue': 215, 'green': 201, 'red': 44}, 'percentage': 14.95},
#       {'rgb': {'blue': 229, 'green': 180, 'red': 30}, 'percentage': 7.43},
#       {'rgb': {'blue': 244, 'green': 241, 'red': 225}, 'percentage': 4.69}]},
#     'type': 'IMAGE_COLOR'}},
#   {'key': 'summary_photo_image_x_large',
#    'value': {'image_value': {'height': 500,
#      'width': 1500,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=png&name=2048x2048_2_exp'},
#     'type': 'IMAGE'}},
#   {'key': 'summary_photo_image',
#    'value': {'image_value': {'height': 314,
#      'width': 600,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=600x314'},
#     'type': 'IMAGE'}},
#   {'key': 'photo_image_full_size_color',
#    'value': {'image_color_value': {'palette': [{'rgb': {'blue': 182,
#         'green': 237,
#         'red': 69},
#        'percentage': 47.44},
#       {'rgb': {'blue': 247, 'green': 161, 'red': 17}, 'percentage': 20.44},
#       {'rgb': {'blue': 215, 'green': 201, 'red': 44}, 'percentage': 14.95},
#       {'rgb': {'blue': 229, 'green': 180, 'red': 30}, 'percentage': 7.43},
#       {'rgb': {'blue': 244, 'green': 241, 'red': 225}, 'percentage': 4.69}]},
#     'type': 'IMAGE_COLOR'}},
#   {'key': 'photo_image_full_size_x_large',
#    'value': {'image_value': {'height': 500,
#      'width': 1500,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=png&name=2048x2048_2_exp'},
#     'type': 'IMAGE'}},
#   {'key': 'card_url',
#    'value': {'scribe_key': 'card_url',
#     'string_value': 'https://t.co/ldzoGfJhLj',
#     'type': 'STRING'}},
#   {'key': 'summary_photo_image_original',
#    'value': {'image_value': {'height': 500,
#      'width': 1500,
#      'url': 'https://pbs.twimg.com/card_img/1825942094449618949/-gct8N2l?format=jpg&name=orig'},
#     'type': 'IMAGE'}}],
#  'card.legacy.card_platform.platform.audience.name': 'production',
#  'card.legacy.card_platform.platform.device.name': 'Swift',
#  'card.legacy.card_platform.platform.device.version': '12',
#  'card.legacy.name': 'summary_large_image',
#  'card.legacy.url': 'https://t.co/ldzoGfJhLj',
#  'card.legacy.user_refs_results': [{'result': {'__typename': 'User',
#     'id': 'VXNlcjoxMzMzNDc2Mg==',
#     'rest_id': '13334762',
#     'affiliates_highlighted_label': {},
#     'has_graduated_access': True,
#     'is_blue_verified': True,
#     'profile_image_shape': 'Square',
#     'legacy': {'can_dm': False,
#      'can_media_tag': True,
#      'created_at': 'Mon Feb 11 04:41:50 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'The AI-powered developer platform to build, scale, and deliver secure software.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'github.com',
#          'expanded_url': 'http://github.com',
#          'url': 'https://t.co/bbJgfyzcJR',
#          'indices': [0, 23]}]}},
#      'fast_followers_count': 0,
#      'favourites_count': 8351,
#      'followers_count': 2592957,
#      'friends_count': 345,
#      'has_custom_timelines': True,
#      'is_translator': False,
#      'listed_count': 18178,
#      'location': 'San Francisco, CA',
#      'media_count': 2387,
#      'name': 'GitHub',
#      'normal_followers_count': 2592957,
#      'pinned_tweet_ids_str': [],
#      'possibly_sensitive': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13334762/1721228108',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1633247750010830848/8zfRrYjA_normal.png',
#      'profile_interstitial_type': '',
#      'screen_name': 'github',
#      'statuses_count': 9174,
#      'translator_type': 'none',
#      'url': 'https://t.co/bbJgfyzcJR',
#      'verified': False,
#      'verified_type': 'Business',
#      'want_retweets': False,
#      'withheld_in_countries': []},
#     'tipjar_settings': {}}}],
#  'views.state': 'Enabled',
#  'legacy.bookmark_count': 0,
#  'legacy.bookmarked': False,
#  'legacy.created_at': 'Wed Aug 21 17:31:37 +0000 2024',
#  'legacy.conversation_id_str': '1826311206619197553',
#  'legacy.display_text_range': [0, 113],
#  'legacy.entities.hashtags': [],
#  'legacy.entities.symbols': [],
#  'legacy.entities.timestamps': [],
#  'legacy.entities.urls': [{'display_url': 'github.com/twitter/commun…',
#    'expanded_url': 'https://github.com/twitter/communitynotes',
#    'url': 'https://t.co/ldzoGfJhLj',
#    'indices': [90, 113]}],
#  'legacy.entities.user_mentions': [{'id_str': '1319036828964454402',
#    'name': 'Community Notes',
#    'screen_name': 'CommunityNotes',
#    'indices': [60, 75]},
#   {'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'indices': [80, 89]}],
#  'legacy.favorite_count': 0,
#  'legacy.favorited': False,
#  'legacy.full_text': 'Turns out Democrat party operatives are using bots to flood @CommunityNotes\ncc: @elonmusk\nhttps://t.co/ldzoGfJhLj',
#  'legacy.is_quote_status': False,
#  'legacy.lang': 'en',
#  'legacy.possibly_sensitive': False,
#  'legacy.possibly_sensitive_editable': True,
#  'legacy.quote_count': 0,
#  'legacy.reply_count': 0,
#  'legacy.retweet_count': 0,
#  'legacy.retweeted': False,
#  'legacy.user_id_str': '20634939',
#  'legacy.id_str': '1826311206619197553'}

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ## 4. Exploration Data Analysis

# %% [markdown]
# ## 5. Data Transformation

# %% [markdown]
# ## 6. Export Transformed Data
