# %% [markdown]
# # ETL Twitter Project: Transform step

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from datetime import datetime
import json

# %% [markdown]
# ## 2. Load Json Dataset

# %%
# Load JSON file

with open('Data/Twitter_User.json') as f:
    data = json.load(f)

if 'data' in data and 'data' in data['data']:
    nested_data = data['data']['data']
else:
    raise ValueError("Unexpected JSON structure.")

df = pd.json_normalize(nested_data)
df.head()
# Out:
#                rest_id  is_translatable  \
# 0  1832795668106166764            False
# 1  1832795665329504674            False
# 2  1832795664767410250            False
# 3  1832795663479771487            False
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="https://mobile.twitter.com" rel="nofo...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
#
#   core.user_results.result.__typename       core.user_results.result.id  \
# 0                                User  VXNlcjoxNDYyODk0NTk0MzI1MDM3MDU3
# 1                                User  VXNlcjoxNjU4MTY1OTIxNjUzOTY0ODAw
# 2                                User  VXNlcjoxNjM1MzU2NDI3NDc1NzM0NTI4
# 3                                User              VXNlcjozMjEwOTc1MDc=
#
#   core.user_results.result.rest_id  \
# 0              1462894594325037057
# 1              1658165921653964800
# 2              1635356427475734528
# 3                        321097507
#
#    core.user_results.result.has_graduated_access  \
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                           True
#
#    core.user_results.result.is_blue_verified  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
#
#   core.user_results.result.profile_image_shape  \
# 0                                       Circle
# 1                                       Circle
# 2                                       Circle
# 3                                       Circle
#
#    core.user_results.result.legacy.can_dm  ...  \
# 0                                   False  ...
# 1                                   False  ...
# 2                                   False  ...
# 3                                   False  ...
#
#    legacy.in_reply_to_status_id_str legacy.in_reply_to_user_id_str  \
# 0               1832448037639352428                       44196397
# 1               1832142752114503811                       44196397
# 2               1832745687944962276            1804797380988162048
# 3               1832785462735352254                       14293310
#
#    legacy.is_quote_status  legacy.lang legacy.quote_count legacy.reply_count  \
# 0                   False           en                  0                  0
# 1                   False           en                  0                  0
# 2                   False           en                  0                  0
# 3                   False           en                  0                  0
#
#    legacy.retweet_count  legacy.retweeted   legacy.user_id_str  \
# 0                     0             False  1462894594325037057
# 1                     0             False  1658165921653964800
# 2                     0             False  1635356427475734528
# 3                     0             False            321097507
#
#          legacy.id_str
# 0  1832795668106166764
# 1  1832795665329504674
# 2  1832795664767410250
# 3  1832795663479771487
#
# [4 rows x 65 columns]

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ## 4. Exploration Data Analysis

# %% [markdown]
# ## 5. Data Transformation

# %% [markdown]
# ## 6. Export Transformed Data
